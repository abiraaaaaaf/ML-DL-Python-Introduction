# %% [markdown]
# <a href="https://colab.research.google.com/github/abiraaaaaaf/ML-DL-Python-Introduction/blob/main/Session_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Concept 1: Pooling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Concept 2: Stride and Filter Size

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Concept 3: Zero Padding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Concept 4: Filters and Feature Maps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Concept 5: Feature Maps Visualization

# %% [markdown]
# ![A-common-widely-shared-example-illustrating-how-neural-networks-learn-hierarchical.png](data:image/png;base64,...)

# %% [markdown]
# ![1-Figure2-1.png](data:image/png;base64,...)

# %% [markdown]
# ![Hierarchical-representation-learning-by-a-Convolutional-Neural-Network-where-the-initial.png](data:image/png;base64,...)

# %% [markdown]
# ## Concept 6: Fully Connected Layers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CNN: Convolutional Neural Network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
